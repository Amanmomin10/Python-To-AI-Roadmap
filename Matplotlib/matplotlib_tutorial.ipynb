# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X = [1,2,3,4]
Y = [5,6,7,8]

plt.plot(X,Y) #line plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Real Data
#Oscar Winner Movies
oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo" 
]
years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232] # in $M

plt.plot(years, oscar_revenue)
plt.xlabel("Years") 
plt.ylabel("Oscar_revenue(in-$M)")  
plt.title("Oscar Winning Movies In Each Year")  
plt.show()

# %%
#Non Oscar Winner Movies
non_oscar_movies = ["Slumdog Millionaire", "Avatar", "Inception", "Hugo", "Lincoln"]
non_oscar_revenue = [378, 2788, 829, 185, 275] # in $M

plt.plot(years, oscar_revenue, "2-r", label = "Oscar Movie")
plt.plot(years, non_oscar_revenue, "<--y", label = "Non-Oscar Movie")

plt.title("Oscar Movie VS Non-Oscar Movie Revenue")
plt.xlabel("Years") 
plt.ylabel("Oscar_revenue(in-$M)")
plt.legend()

# %%
oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo" 
]
years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232] # in $M

plt.bar(years, oscar_revenue, color = "g")
plt.xlabel("Years") 
plt.ylabel("Oscar_revenue(in-$M)")  
plt.title("Revenue In Each Year For Oscar Movies")

for i in range(len(years)):
    plt.text(years[i], oscar_revenue[i]+10, str(oscar_revenue[i]), ha="center" )

# %%
oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo" 
]
oscar_revenue = [1005, 170, 427, 133, 232] # in $M
non_oscar_movies = ["Slumdog Millionaire", "Avatar", "Inception", "Hugo", "Lincoln"]
non_oscar_revenue = [378, 2788, 829, 185, 275] # in $M
years = [2008, 2009, 2010, 2011, 2012]

x = np.arange(len(years))
width = 0.25

plt.title("Oscar vs Non-Oscar Revenue")
plt.xlabel("Years") 
plt.ylabel("Revenue(in-$M)") 
  
plt.bar(x-width, oscar_revenue, width)
plt.bar(x, non_oscar_revenue, width)
plt.bar(x+width, oscar_revenue, width)
plt.xticks(x, years)
# Out:
# ([<matplotlib.axis.XTick at 0x1e1d8e02710>,
#   <matplotlib.axis.XTick at 0x1e1d9199e50>,
#   <matplotlib.axis.XTick at 0x1e1d919a5d0>,
#   <matplotlib.axis.XTick at 0x1e1d919ad50>,
#   <matplotlib.axis.XTick at 0x1e1d919b4d0>],
#  [Text(0, 0, '2008'),
#   Text(1, 0, '2009'),
#   Text(2, 0, '2010'),
#   Text(3, 0, '2011'),
#   Text(4, 0, '2012')])

# %%
oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo" 
]
oscar_revenue = [1005, 170, 427, 133, 232] # in $M

plt.barh(oscar_movies, oscar_revenue)
plt.xlabel("oscar_revenue") 
plt.ylabel("oscar_movies")
# Out:
# Text(0, 0.5, 'oscar_movies')

# %%
# Scatter Plots
people = ["Person A", "Person B", "Person C", "Person D", "Person E",
          "Person F","Person G","Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
bp = [110, 115, 120, 122, 125, 130, 135, 123, 145, 159]

plt.scatter(age, bp)
plt.title("Age vs BP")
plt.xlabel("Age") 
plt.ylabel("Blood Pressure")
# Out:
# Text(0, 0.5, 'Blood Pressure')

# %%
from scipy.stats import binom

n = 5
k = 3
p = 0.5

prob = binom.pmf(k, n, p)
print(prob)
# Out:
# 0.31249999999999983

# %%
# Task
days = ["Mon","Tue", "Wed", "Thu", "Fri"]

cities = ["New York", "London", "Delhi","Tokyo"]

temperatures = [
    [22, 23, 21, 24, 25], # New York
    [18, 19, 17, 20, 21], # London
    [30, 32, 31, 33, 34], # Delhi
    [25, 26, 24, 27, 28]  # Tokyo
]

fig, axes = plt.subplots(2, 2)
city_no = 0
for i in range(2):
    for j in range(2):
        axes[i][j].plot(days, temperatures[city_no], marker = "o")
        axes[i][j].set_title(cities[city_no])
        axes[i][j].grid(True)
        city_no = city_no + 1
        
fig.suptitle("Temperature in cities over the week")
fig.supylabel("")
fig.supxlabel("")

fig.tight_layout()
