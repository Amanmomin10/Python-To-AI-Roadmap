# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
#from sklearn.cluster import

# %%
df = pd.read_csv("smartcart_customers.csv")

# %%
df.head()
# Out:
#      ID  Year_Birth   Education  ... NumWebVisitsMonth  Complain  Response
# 0  5524        1957  Graduation  ...                 7         0         1
# 1  2174        1954  Graduation  ...                 5         0         0
# 2  4141        1965  Graduation  ...                 4         0         0
# 3  6182        1984  Graduation  ...                 6         0         0
# 4  5324        1981         PhD  ...                 5         0         0
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  Complain             2240 non-null   int64
#  21  Response             2240 non-null   int64
# dtypes: float64(1), int64(18), object(3)
# memory usage: 385.1+ KB

# %%
df.describe()
# Out:
#                  ID   Year_Birth  ...     Complain     Response
# count   2240.000000  2240.000000  ...  2240.000000  2240.000000
# mean    5592.159821  1968.805804  ...     0.009375     0.149107
# std     3246.662198    11.984069  ...     0.096391     0.356274
# min        0.000000  1893.000000  ...     0.000000     0.000000
# 25%     2828.250000  1959.000000  ...     0.000000     0.000000
# 50%     5458.500000  1970.000000  ...     0.000000     0.000000
# 75%     8427.750000  1977.000000  ...     0.000000     0.000000
# max    11191.000000  1996.000000  ...     1.000000     1.000000
#
# [8 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Complain                0
# Response                0
# dtype: int64

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #1. Handle Missing Values

# %%
df["Income"] = df["Income"].fillna(df["Income"].median())

# %%
df.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Complain               0
# Response               0
# dtype: int64

# %%
df.head()
# Out:
#      ID  Year_Birth   Education  ... NumWebVisitsMonth  Complain  Response
# 0  5524        1957  Graduation  ...                 7         0         1
# 1  2174        1954  Graduation  ...                 5         0         0
# 2  4141        1965  Graduation  ...                 4         0         0
# 3  6182        1984  Graduation  ...                 6         0         0
# 4  5324        1981         PhD  ...                 5         0         0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Feature Engineering

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Complain', 'Response'],
#       dtype='object')

# %%
#Age
df["Age"] = 2026-df["Year_Birth"]

# %%
df.head()
# Out:
#      ID  Year_Birth   Education  ... Complain  Response  Age
# 0  5524        1957  Graduation  ...        0         1   69
# 1  2174        1954  Graduation  ...        0         0   72
# 2  4141        1965  Graduation  ...        0         0   61
# 3  6182        1984  Graduation  ...        0         0   42
# 4  5324        1981         PhD  ...        0         0   45
#
# [5 rows x 23 columns]

# %%
# Customer Joining Date
df["Dt_Customer"] = pd.to_datetime(df["Dt_Customer"], dayfirst=True)

reference_date = df["Dt_Customer"].max()

df["Customer_Tenure_Days"] = (reference_date - df["Dt_Customer"]).dt.days

# %%
df.head()
# Out:
#      ID  Year_Birth   Education  ... Response  Age  Customer_Tenure_Days
# 0  5524        1957  Graduation  ...        1   69                   663
# 1  2174        1954  Graduation  ...        0   72                   113
# 2  4141        1965  Graduation  ...        0   61                   312
# 3  6182        1984  Graduation  ...        0   42                   139
# 4  5324        1981         PhD  ...        0   45                   161
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Complain', 'Response', 'Age', 'Customer_Tenure_Days'],
#       dtype='object')

# %%
# Spending
df["Total_Spending"] = df["MntWines"]+df["MntFruits"]+df["MntMeatProducts"]+df["MntFishProducts"]+df["MntSweetProducts"]+df["MntGoldProds"]

# Children
df["Total_Children"] = df["Kidhome"]+df["Teenhome"]

# %%
df.head()
# Out:
#      ID  Year_Birth  ... Total_Spending Total_Children
# 0  5524        1957  ...           1617              0
# 1  2174        1954  ...             27              2
# 2  4141        1965  ...            776              0
# 3  6182        1984  ...             53              1
# 4  5324        1981  ...            422              1
#
# [5 rows x 26 columns]

# %%
df["Education"].value_counts()
# Out:
# Education
# Graduation    1127
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %%
# Education

df["Education"] = df["Education"].replace({
        "Basic" : "Undergraduate",
        "2n Cycle" : "Undergraduate",
        "Graduation" : "Graduate",
        "Master" : "Postgraduate",
        "PhD" : "Postgraduate"
})

# %%
df["Marital_Status"].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# Absurd        2
# YOLO          2
# Name: count, dtype: int64

# %%
# Maratial Status

df["Living_With"] = df["Marital_Status"].replace({
        "Married" : "Partner",
        "Together" : "Partner",
        "Single" : "Alone",
        "Divorced" : "Alone",
        "Widow" : "Alone",
        "Absurd" : "Alone",
        "YOLO" : "Alone",
})

# %%
df["Living_With"].value_counts()
# Out:
# Living_With
# Partner    1444
# Alone       796
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#      ID  Year_Birth     Education  ... Total_Spending  Total_Children  Living_With
# 0  5524        1957      Graduate  ...           1617               0        Alone
# 1  2174        1954      Graduate  ...             27               2        Alone
# 2  4141        1965      Graduate  ...            776               0      Partner
# 3  6182        1984      Graduate  ...             53               1      Partner
# 4  5324        1981  Postgraduate  ...            422               1      Partner
# 5  7446        1967  Postgraduate  ...            716               1      Partner
# 6   965        1971      Graduate  ...            590               1        Alone
# 7  6177        1985  Postgraduate  ...            169               1      Partner
# 8  4855        1974  Postgraduate  ...             46               1      Partner
# 9  5899        1950  Postgraduate  ...             49               2      Partner
#
# [10 rows x 27 columns]

# %%
df.shape
# Out:
# (2240, 27)

# %%
# Dropping Unnecessary columns

cols = ["ID", "Year_Birth", "Marital_Status", "Kidhome","Teenhome", "Dt_Customer"]
spending = ["MntWines", "MntFruits", "MntMeatProducts", "MntFishProducts", "MntSweetProducts", "MntGoldProds"]

cols_to_drop = cols + spending

df_cleaned = df.drop(columns = cols_to_drop)

# %%
df_cleaned.shape
# Out:
# (2240, 15)

# %%
df_cleaned.head(10)
# Out:
#       Education   Income  Recency  ...  Total_Spending  Total_Children  Living_With
# 0      Graduate  58138.0       58  ...            1617               0        Alone
# 1      Graduate  46344.0       38  ...              27               2        Alone
# 2      Graduate  71613.0       26  ...             776               0      Partner
# 3      Graduate  26646.0       26  ...              53               1      Partner
# 4  Postgraduate  58293.0       94  ...             422               1      Partner
# 5  Postgraduate  62513.0       16  ...             716               1      Partner
# 6      Graduate  55635.0       34  ...             590               1        Alone
# 7  Postgraduate  33454.0       32  ...             169               1      Partner
# 8  Postgraduate  30351.0       19  ...              46               1      Partner
# 9  Postgraduate   5648.0       68  ...              49               2      Partner
#
# [10 rows x 15 columns]

# %% [markdown]
# ### Handling Outliers

# %%
cols = ["Income", "Recency", "Response", "Age", "Total_Spending", "Total_Children"]

sns.pairplot(df_cleaned[cols])

# %%
# Remove Outliers

print("Data size with utliers", len(df_cleaned))

df_cleaned = df_cleaned [ (df_cleaned["Age"] < 90) ]
df_cleaned = df_cleaned [ (df_cleaned["Income"] < 600_000) ]

print("Data size without utliers", len(df_cleaned))
# Out:
# Data size with utliers 2240
# Data size without utliers 2236

# %% [markdown]
# ### Heat-map Correlation

# %%
corr = df_cleaned.corr(numeric_only=True)

# %%
corr
# Out:
#                         Income   Recency  ...  Total_Spending  Total_Children
# Income                1.000000  0.007829  ...        0.789375       -0.340550
# Recency               0.007829  1.000000  ...        0.020842        0.017826
# NumDealsPurchases    -0.107169 -0.000638  ...       -0.064831        0.439682
# NumWebPurchases       0.450584 -0.010776  ...        0.519948       -0.146429
# NumCatalogPurchases   0.693781  0.025226  ...        0.778343       -0.439631
# NumStorePurchases     0.628075  0.000771  ...        0.675460       -0.321729
# NumWebVisitsMonth    -0.646382 -0.021850  ...       -0.499909        0.417908
# Complain             -0.027871  0.005361  ...       -0.033784        0.031480
# Response              0.161121 -0.198781  ...        0.265615       -0.169451
# Age                   0.198835  0.019396  ...        0.113618        0.095512
# Customer_Tenure_Days -0.023677  0.024238  ...        0.158764       -0.025742
# Total_Spending        0.789375  0.020842  ...        1.000000       -0.498579
# Total_Children       -0.340550  0.017826  ...       -0.498579        1.000000
#
# [13 rows x 13 columns]

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    corr,
    annot=True,
    annot_kws={"size": 6},
    cmap="coolwarm"
)
# Out:
# <Axes: >

# %%
df_cleaned.shape
# Out:
# (2236, 15)

# %%
df_cleaned.head()
# Out:
#       Education   Income  Recency  ...  Total_Spending  Total_Children  Living_With
# 0      Graduate  58138.0       58  ...            1617               0        Alone
# 1      Graduate  46344.0       38  ...              27               2        Alone
# 2      Graduate  71613.0       26  ...             776               0      Partner
# 3      Graduate  26646.0       26  ...              53               1      Partner
# 4  Postgraduate  58293.0       94  ...             422               1      Partner
#
# [5 rows x 15 columns]

# %% [markdown]
# ### Feature Encoding

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()

cat_cols = ["Education", "Living_With"]

enc_cols = ohe.fit_transform(df_cleaned[cat_cols])

# %%
enc_df = pd.DataFrame(enc_cols.toarray(), columns=ohe.get_feature_names_out(cat_cols), index=df_cleaned.index)

# %%
df_encoded = pd.concat([df_cleaned.drop(columns=cat_cols), enc_df], axis =1)

# %%
df_encoded.shape
# Out:
# (2236, 18)

# %%
df_encoded.head()
# Out:
#     Income  Recency  ...  Living_With_Alone  Living_With_Partner
# 0  58138.0       58  ...                1.0                  0.0
# 1  46344.0       38  ...                1.0                  0.0
# 2  71613.0       26  ...                0.0                  1.0
# 3  26646.0       26  ...                0.0                  1.0
# 4  58293.0       94  ...                0.0                  1.0
#
# [5 rows x 18 columns]

# %% [markdown]
# ### Scaling

# %%
X = df_encoded

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Visualize

# %%
X_scaled.shape
# Out:
# (2236, 18)

# %%
#2D

from sklearn.decomposition import PCA

pca = PCA(
    n_components=3
)
X_pca = pca.fit_transform(X_scaled)

# %%
# plot
fig = plt.figure(figsize=(8, 6))

ax = fig.add_subplot(111, projection="3d")

ax.scatter(
    X_pca[:,0],
    X_pca[:,1],
    X_pca[:,2]
)

ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
ax.set_title("3D projection")
# Out:
# Text(0.5, 0.92, '3D projection')

# %%
pca.explained_variance_ratio_
# Out:
# array([0.23163158, 0.11385454, 0.10405815])

# %% [markdown]
# ## Analyze K Value

# %% [markdown]
# ### 1.Elbow Method

# %%
from sklearn.cluster import KMeans
from kneed import KneeLocator

wcss = []
for k in range(1, 11):
    Kmeans = KMeans(n_clusters=k, random_state=42)
    Kmeans.fit_predict(X_pca)
    wcss.append(Kmeans.inertia_)

# %%
knee = KneeLocator(range(1, 11), wcss, curve="convex", direction="decreasing")
optimal_k = knee.elbow

# %%
print("optimal_k : ", optimal_k)
# Out:
# optimal_k :  4

# %%
plt.plot(range(1, 11),
    wcss,
    marker="o"
)
plt.xlabel("K")
plt.ylabel("WCSS")
plt.title("K vs WCSS")
# Out:
# Text(0.5, 1.0, 'K vs WCSS')

# %% [markdown]
# ### Silhouette Score

# %%
from sklearn.metrics import silhouette_score

# %%
scores = []
for k in range(2, 11):
    Kmeans = KMeans(n_clusters=k, random_state=42)
    labels = Kmeans.fit_predict(X_pca)
    score = silhouette_score(X_pca, labels)
    scores.append(score)

# %%
plt.plot(range(2, 11),
    scores,
    marker="o"
)
plt.xlabel("K")
plt.ylabel("Scores")
plt.title("K vs Scores")
# Out:
# Text(0.5, 1.0, 'K vs Scores')

# %%
#Combined plot

k_range = range(2,11)
fig, ax1 = plt.subplots(figsize=(8, 6))
 
# First axis (WCSS)
ax1.plot(k_range, wcss[:len(k_range)], marker="o", color= "blue")
ax1.set_xlabel("K")
ax1.set_ylabel("WCSS")

# Second axis (Silhouette)
ax2 = ax1.twinx()
ax2.plot(k_range, scores[:len(k_range)], marker="x", color= "red", linestyle="--")
ax2.set_ylabel("Silhouette Score")

plt.title("K vs WCSS & Silhouette Score")
plt.show()

# %% [markdown]
# ### Clustering

# %%
kmeans = KMeans(
    n_clusters=4, 
    random_state=4
)
labels_kmeans = kmeans.fit_predict(X_pca)

# %%
# plot
fig = plt.figure(figsize=(8, 6))

ax = fig.add_subplot(111, projection="3d")

ax.scatter(
    X_pca[:,0],
    X_pca[:,1],
    X_pca[:,2],
    c=labels_kmeans
)

ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
ax.set_title("3D projection")
# Out:
# Text(0.5, 0.92, '3D projection')

# %%
from sklearn.cluster import  AgglomerativeClustering

# %%
agg_clf = AgglomerativeClustering(
    n_clusters=4,
    linkage="ward"
)
labels_agg = agg_clf.fit_predict(X_pca)

# %%
# plot
fig = plt.figure(figsize=(8, 6))

ax = fig.add_subplot(111, projection="3d")

ax.scatter(
    X_pca[:,0],
    X_pca[:,1],
    X_pca[:,2],
    c=labels_agg
)

ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
ax.set_title("3D projection")
# Out:
# Text(0.5, 0.92, '3D projection')

# %% [markdown]
# ### Characterization of cluster

# %%
X["cluster"]= labels_agg

# %%
X.head()
# Out:
#     Income  Recency  ...  Living_With_Partner  cluster
# 0  58138.0       58  ...                  0.0        3
# 1  46344.0       38  ...                  0.0        2
# 2  71613.0       26  ...                  1.0        1
# 3  26646.0       26  ...                  1.0        0
# 4  58293.0       94  ...                  1.0        0
#
# [5 rows x 19 columns]

# %%
pal = ["red", "blue", "yellow", "green"]

sns.countplot(
    x=X["cluster"],
    palette=pal,
    hue=X["cluster"]
)
# Out:
# <Axes: xlabel='cluster', ylabel='count'>

# %%
sns.scatterplot(x=X["Total_Spending"],
                y =X["Income"],
                hue = X["cluster"],
                palette=pal
                )
# Out:
# <Axes: xlabel='Total_Spending', ylabel='Income'>

# %%
#Cluster Summary

cluster_summary = X.groupby("cluster").mean()
print(cluster_summary)
# Out:
#                Income    Recency  ...  Living_With_Alone  Living_With_Partner
# cluster                           ...
# 0        39680.580110  48.914917  ...           0.000000             1.000000
# 1        72808.445693  49.202247  ...           0.000000             1.000000
# 2        36960.143018  48.319820  ...           0.993243             0.006757
# 3        70722.681303  50.504249  ...           1.000000             0.000000
#
# [4 rows x 18 columns]
